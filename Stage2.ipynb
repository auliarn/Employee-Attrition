# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
from scipy import stats
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 12, 4
rcParams['lines.linewidth'] = 3
rcParams['xtick.labelsize'] = 'x-large'
rcParams['ytick.labelsize'] = 'x-large'

# %%
# Load dataset
df = pd.read_csv('HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %% [markdown]
# # Drop Kolom

# %%
#cats = df.select_dtypes('object').columns.tolist()

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
#df[cats].describe()

# %%
#df_corr = df.copy()
#mapping_attrition = {
 #   'Yes': 1,
  #  'No' : 0
#}
#df_corr['Attrition']=df_corr['Attrition'].map(mapping_attrition)
#df_corr.head(2)

# %%
#plt.figure(figsize=(23, 12))
#sns.heatmap(df_corr.corr(), annot=True, fmt='.2f')

# %%
# Drop kolom EmployeeCount, EmployeeNumber, StandardHours, Over18
df1 = df.copy()
df1 = df.drop(['EmployeeCount','EmployeeNumber','StandardHours','Over18'], axis=1)

df1.shape
# Out:
# (1470, 31)

# %% [markdown]
# # Ubah Tipe Data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# Ada kolom yang tipe datanya tidak sesuai, sehingga akan diubah tipe datanya terlebih dahulu

# %%
to_category = ['Education', 'EnvironmentSatisfaction', 'JobInvolvement','JobLevel','JobSatisfaction','PerformanceRating','RelationshipSatisfaction','StockOptionLevel','WorkLifeBalance']
for x in to_category:
  df1[x] = df1[x].astype('str')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   object
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   object
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   object
#  12  JobLevel                  1470 non-null   object
# ...

# %% [markdown]
# # Handle the Missing Values

# %%
df1.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %% [markdown]
# Tidak ada data yang bernilai kosong/missing value

# %% [markdown]
# # Duplicate

# %%
df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Tidak ada data duplicate

# %% [markdown]
# # Handle the Outliers

# %%
nums = df1.select_dtypes('number').columns.tolist()
cats = df1.select_dtypes('object').columns.tolist()

# %%
features = nums
plt.figure(figsize=(15, 8))
for i in range(0, len(nums)):
    plt.subplot(5, len(nums)/4, i+1)
    sns.boxplot(x=df[features[i]], color='green')
    plt.xlabel(features[i])
    plt.tight_layout()

# %% [markdown]
# Kami memutuskan untuk tidak membuang outliers dikarenakan:
# * Keseluruhan fitur memiliki standard deviasi yang tidak terlalu besar, distribusi normal.
# * Fitur paling memungkinkan untuk dilakukan drop outliers adalah `PerformanceRating` menggunakan penghapusan filter score >3.5  , namun setelah dikaji bersama tidak dipustuskan untuk dihapus karena akan menghasilkan fitur dengan nilai value konstan (hanya ada value 3 dari value 3 dan 4).
# * `YearsSinceLastPromotion` merupakan fitur yang identik dengan tahun dan dianggap tidak memiliki outlier. Fitur yang akan dicek dan dianggap memiliki outlier adalah fitur dengan nilai angka atau uang (*continuous*).
#
# *note*: *boxplot* hanya bisa membaca angka

# %% [markdown]
# # Label Encoding

# %%
df2 = df1.copy()

# %%
df2.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome Education EducationField EnvironmentSatisfaction  Gender  \
# 0                 1         2  Life Sciences                       2  Female
# 1                 8         1  Life Sciences                       3    Male
#
#    HourlyRate JobInvolvement JobLevel             JobRole JobSatisfaction  \
# 0          94              3        2     Sales Executive               4
# 1          61              2        2  Research Scientist               2
#
#   MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked OverTime  \
# 0        Single           5993        19479                   8      Yes
# 1       Married           5130        24907                   1       No
#
#    PercentSalaryHike PerformanceRating RelationshipSatisfaction  \
# ...

# %%
replacement_mapping_dict_edu = {
    '1': 'Below College',
    '2' : 'College',
    '3' : 'Bachelor',
    '4' : 'Master',
    '5' : 'Doctor'
}

replacement_mapping_dict_satisfaction = {
    '1': 'Low',
    '2' : 'Medium',
    '3' : 'High',
    '4' : 'Very High'
}

replacement_mapping_dict_performance = {
    '1': 'Low',
    '2' : 'Good',
    '3' : 'Excellent',
    '4' : 'Outstanding'
}

replacement_mapping_dict_worklife = {
    '1': 'Low',
    '2' : 'Good',
    '3' : 'Better',
    '4' : 'Best'
}

df2['Education'] = df2['Education'].replace(replacement_mapping_dict_edu)
df2['EnvironmentSatisfaction'] = df2['EnvironmentSatisfaction'].replace(replacement_mapping_dict_satisfaction)
df2['JobInvolvement'] = df2['JobInvolvement'].replace(replacement_mapping_dict_satisfaction)
df2['JobSatisfaction'] = df2['JobSatisfaction'].replace(replacement_mapping_dict_satisfaction)
df2['RelationshipSatisfaction'] = df2['RelationshipSatisfaction'].replace(replacement_mapping_dict_satisfaction)
df2['PerformanceRating'] = df2['PerformanceRating'].replace(replacement_mapping_dict_performance)
df2['WorkLifeBalance'] = df2['WorkLifeBalance'].replace(replacement_mapping_dict_worklife)

# %%
df2.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                 1        College  Life Sciences                  Medium
# 1                 8  Below College  Life Sciences                    High
# 2                 2        College          Other               Very High
# 3                 3         Master  Life Sciences               Very High
# 4                 2  Below College        Medical                     Low
#
#    Gender  HourlyRate JobInvolvement JobLevel                JobRole  \
# ...

# %%
#df2.nunique()

# %%
#Categorical variables cannot be handled without encoding. The solution is the feature encoding.

df3 = pd.get_dummies(df2)
df3
# Out:
#       Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# 0      41       1102                 1          94           5993
# 1      49        279                 8          61           5130
# 2      37       1373                 2          92           2090
# 3      33       1392                 3          56           2909
# 4      27        591                 2          40           3468
# ...   ...        ...               ...         ...            ...
# 1465   36        884                23          41           2571
# 1466   39        613                 6          42           9991
# 1467   27        155                 4          87           6142
# 1468   49       1023                 2          63           5390
# 1469   34        628                 8          82           4404
#
#       MonthlyRate  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0           19479                   8                 11                  8
# ...

# %%
df3 = df3.drop(['Attrition_No','OverTime_No','Gender_Female'],axis=1)
df3 = df3.rename(columns = {'Attrition_Yes' : 'Attrition', 'OverTime_Yes' : 'OverTime','Gender_Male':'Gender'})
df3.head(2)
# Out:
#    Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  MonthlyRate  \
# 0   41       1102                 1          94           5993        19479
# 1   49        279                 8          61           5130        24907
#
#    NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0                   8                 11                  8
# 1                   1                 23                 10
#
#    TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# 0                      0               6                   4
# 1                      3              10                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition  \
# 0                        0                     5          1
# 1                        1                     7          0
#
#    BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                          0                                 0
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 77 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Age                                 1470 non-null   int64
#  1   DailyRate                           1470 non-null   int64
#  2   DistanceFromHome                    1470 non-null   int64
#  3   HourlyRate                          1470 non-null   int64
#  4   MonthlyIncome                       1470 non-null   int64
#  5   MonthlyRate                         1470 non-null   int64
#  6   NumCompaniesWorked                  1470 non-null   int64
#  7   PercentSalaryHike                   1470 non-null   int64
#  8   TotalWorkingYears                   1470 non-null   int64
#  9   TrainingTimesLastYear               1470 non-null   int64
#  10  YearsAtCompany                      1470 non-null   int64
# ...

# %% [markdown]
# ## Feature Scaling Standarization

# %%
from sklearn.preprocessing import StandardScaler

df4 = df3
# Removing Categorical Features before the feature scaling
columns = df3.columns

# Continous col
columns_cont = np.delete(columns,np.s_[14:])

# Categorical col
columns_categorical = np.delete(columns,np.s_[0:14])

# except age since it is discretized and attrition and overtime
#except_age_cont = np.delete(columns_cont, [0])

# Applying Standardization 
# Init StandardScaler
scaler = StandardScaler()

#Transformation of training dataset features
Except = pd.DataFrame(df4, columns = columns_cont)
scaler.fit(Except)

df4 = pd.DataFrame(scaler.transform(Except), columns = columns_cont).join(df3[columns_categorical])

# %%
df4
# Out:
#            Age  DailyRate  DistanceFromHome  Education  \
# 0     0.446350   0.742527         -1.010909  -0.891688
# 1     1.322365  -1.297775         -0.147150  -1.868426
# 2     0.008343   1.414363         -0.887515  -0.891688
# 3    -0.429664   1.461466         -0.764121   1.061787
# 4    -1.086676  -0.524295         -0.887515  -1.868426
# ...        ...        ...               ...        ...
# 1465 -0.101159   0.202082          1.703764  -0.891688
# 1466  0.227347  -0.469754         -0.393938  -1.868426
# 1467 -1.086676  -1.605183         -0.640727   0.085049
# 1468  1.322365   0.546677         -0.887515   0.085049
# 1469 -0.320163  -0.432568         -0.147150   0.085049
#
#       EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                   -0.660531    1.383138        0.379672 -0.057788
# 1                    0.254625   -0.240677       -1.026167 -0.057788
# 2                    1.169781    1.284725       -1.026167 -0.961486
# ...

# %% [markdown]
# # Class Imbalance

# %% [markdown]
# Karena data target tidak seimbang atau sangat timpang, maka akan dilakukan teknik oversampling/undersampling/SMOTE.

# %%
X = df4.drop('Attrition', axis=1)
X
# Out:
#            Age  DailyRate  DistanceFromHome  HourlyRate  MonthlyIncome  \
# 0     0.446350   0.742527         -1.010909    1.383138      -0.108350
# 1     1.322365  -1.297775         -0.147150   -0.240677      -0.291719
# 2     0.008343   1.414363         -0.887515    1.284725      -0.937654
# 3    -0.429664   1.461466         -0.764121   -0.486709      -0.763634
# 4    -1.086676  -0.524295         -0.887515   -1.274014      -0.644858
# ...        ...        ...               ...         ...            ...
# 1465 -0.101159   0.202082          1.703764   -1.224807      -0.835451
# 1466  0.227347  -0.469754         -0.393938   -1.175601       0.741140
# 1467 -1.086676  -1.605183         -0.640727    1.038693      -0.076690
# 1468  1.322365   0.546677         -0.887515   -0.142264      -0.236474
# 1469 -0.320163  -0.432568         -0.147150    0.792660      -0.445978
#
#       MonthlyRate  NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# ...

# %%
y = df4['Attrition']
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: uint8

# %%
from imblearn import under_sampling, over_sampling
X_under, y_under = under_sampling.RandomUnderSampler(0.5).fit_resample(X, y)
X_over, y_over = over_sampling.RandomOverSampler(0.5).fit_resample(X, y)
X_over_SMOTE, y_over_SMOTE = over_sampling.SMOTE(0.5).fit_resample(X, y)

# %%
print('Original')
print(pd.Series(y).value_counts())
print('\n')
print('UNDERSAMPLING')
print(pd.Series(y_under).value_counts())
print('\n')
print('OVERSAMPLING')
print(pd.Series(y_over).value_counts())
print('\n')
print('SMOTE')
print(pd.Series(y_over_SMOTE).value_counts())
# Out:
# Original
# 0    1233
# 1     237
# Name: Attrition, dtype: int64
#
#
# UNDERSAMPLING
# 0    474
# 1    237
# Name: Attrition, dtype: int64
#
#
# OVERSAMPLING
# 0    1233
# 1     616
# Name: Attrition, dtype: int64
#
#
# SMOTE
# 0    1233
# 1     616
# Name: Attrition, dtype: int64

# %% [markdown]
# # Split the Data

# %% [markdown]
# ### Data Undersampling

# %%
from sklearn.model_selection import train_test_split
X_under_train, X_under_test, y_under_train, y_under_test = train_test_split(X_under,y_under,test_size=0.2,random_state=42)

# %%
print(X_under_train.shape)
print(X_under_test.shape)
# Out:
# (568, 77)
# (143, 77)

# %% [markdown]
# ### Data Oversampling

# %%
from sklearn.model_selection import train_test_split
X_over_train, X_over_test, y_over_train, y_over_test = train_test_split(X_over,y_over,test_size=0.2,random_state=42)

# %%
print(X_over_train.shape)
print(X_over_test.shape)
# Out:
# (1479, 77)
# (370, 77)

# %% [markdown]
# ### Data SMOTE

# %%
from sklearn.model_selection import train_test_split
X_over_SMOTE_train, X_over_SMOTE_test, y_over_SMOTE_train, y_over_SMOTE_test = train_test_split(X_over_SMOTE,y_over_SMOTE,test_size=0.2,random_state=42)

# %%
print(X_over_SMOTE_train.shape)
print(X_over_SMOTE_test.shape)
# Out:
# (1479, 77)
# (370, 77)

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#sc_Xr = StandardScaler()
#X_under_train = sc_X.fit_transform(X_under_train)
#X_under_test = sc_X.transform(X_under_test)

# %% [markdown]
# ## Feature Selection

# %%
x = df4.drop('Attrition',axis=1)
y = df4['Attrition']

# %%
from sklearn.ensemble import ExtraTreesClassifier
extra_tree = ExtraTreesClassifier()
extra_tree.fit(x,y)
feat_importance = extra_tree.feature_importances_

# %%
plt.figure(figsize=(11,9))
feat_imp = pd.Series(extra_tree.feature_importances_, index=x.columns)
feat_imp.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# - `OverTime` memiliki hubungan yang paling tinggi dengan attrition. Karyawan yang melakukan lembur lebih banyak meninggalkan perusahaan
# - Faktor yang kedua adalah `Age` (Umur). Hal ini mungkin terjadi karena karyawan yang sudah senior akan meninggalkan perusahaan untuk pensiun.
# - `MonthlyIncome` juga menjadi faktor yang bertanggung jawab akan terjadinya attrition

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# Employment rates are shown for four age groups: people aged 15-64 (the working age population): people aged 15 to 24 (those just entering the labour market following education); people aged 25 to 54 (those in their prime working lives); people aged 55 to 64 (those passing the peak of their career and approaching retirement)
#
# (OECD (2022), Employment rate by age group (indicator). doi: 10.1787/084f32c7-en (Accessed on 03 April 2022)
#
# [Employment rate by age group](https://data.oecd.org/emp/employment-rate-by-age-group.htm#:~:text=Employment%20rates%20are%20shown%20for%20four%20age%20groups%3A,the%20peak%20of%20their%20career%20and%20approaching%20retirement%29.)

# %%
df1['AgeClassification']=np.where(df1['Age'] > 54, 'Senior Age', 
                                 np.where(df1['Age'] > 24, 'Prime Age', 'Entry Level Age'))

# %%
df1.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome Education EducationField EnvironmentSatisfaction  Gender  \
# 0                 1         2  Life Sciences                       2  Female
# 1                 8         1  Life Sciences                       3    Male
# 2                 2         2          Other                       4    Male
# 3                 3         4  Life Sciences                       4  Female
# 4                 2         1        Medical                       1    Male
#
# ...

# %%
sns.countplot(x = df1['AgeClassification'], orient='v')
